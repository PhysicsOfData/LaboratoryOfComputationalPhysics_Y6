# %% [markdown]
# #0\. Implement a function (whatever you want) and save it to a file (e.g. `function.py`). Import that file and use that function in this notebook.
# from my_functions import add_numbers
# result = add_numbers(5,7)
# print(result)

# %% [markdown]
# #1\. Write the following as a list comprehension
# #ans = []
# #for i in range(3):
# #    for j in range(4):
# #       ans.append((i, j))
# #print (ans)
#
# ans = [(i, j) for i in range(3) for j in range(4)]
# print(ans)
#
# # 2
# #ans = map(lambda x: x*x, filter(lambda x: x%2 == 0, range(5)))
# #print (list(ans))
#
# ans = [x*x for x in range(5) if x%2 == 0]
# print(ans)

# %% [markdown]
# #2\. Convert the following function into a pure function with no global variables or side effects
# #x = 5
# #def f(alist):
# #    for i in range(x):
# #         alist.append(i)
# #    return alist
#
# #alist = [1,2,3]
# #ans = f(alist)
# #print (ans)
# #print (alist) # alist has been changed!
#
#
# def f(alist):
#     x = alist.copy()
#     for i in range(5):
#          x.append(i)
#     return x
#
# alist = [1,2,3]
# ans = f(alist)
# print (ans)
# print (alist)
# #praticamente non voglio che alist cambi, e per fare questo copio alist, ma perchè non cambia?
# #mi verrebbe da cambiargli il nome

# %% [markdown]
# #3\. Write a `decorator` hello that makes every wrapped function print “Hello!”, i.e. something like:
#
# #```python
# #@hello
# #def square(x):
# #    return x*x
# #```
# def hello(func):
#     def wrapper(x):
#         print("Hello!")
#         a = func(x)
#         return a
#     return wrapper
#
# @hello
# def square(x):
#     return x * x
#
# result = square(5)
# print("Result:",result)

# %% [markdown]
# #4\. Write the factorial function so that it
# #a) does and
#
# def factorial_recursive(n):
#     if n == 0: #caso base: parto da 0, poi faccio il prodotto di tutti i numeri fino ad n compreso
#         return 1
#     else: #caso recursivo: praticamente fa n*fr(n-1) che a sua volta chiama il fr di n-1, ovvero n-1*fr(n-2) e così via
#         return n * factorial_recursive(n - 1) #devo quindi ricordarmi di chiamare la funzione
#
# result1 = fr(5)
# print(result1)
#
# #b) does not use recursion (using a loop).
#
# def factorial_nonrecursive(n):
#     result2 = 1
#     for i in range(1, n + 1):
#         result2 *= i
#     return result2
# result2 = factorial_nonrecursive(5)
# print(result2)

# %% [markdown]
# #5\. Use HOFs (zip in particular) to compute the weight of a circle, a disk and a sphere, assuming different radii and different densities:
# #where the entries of the dictionary's values are the linear, superficial and volumetric densities of the materials respectively.
# #In particular define a list of three lambda functions using a comprehension that computes the circumference, the area and the volume for a given radius.
#
# # Define the densities dictionary and radii list
# densities = {"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}#linear, superficiale and volumetric densities
# radii = [1,2,3]# vari raggi
#
# # Define a list of lambda functions using comprehensions
# # These lambda functions calculate the circumference, area, and volume for a given radius
# functions = [lambda r: 2*3.14*r,
#              lambda r: 3.14*r**2,
#              lambda r: (4/3)*3.14*r**3
#             ]
# # Calculate and print the weight for each combination of radius and density using zip
# weights = [(material, r, [func(r) * density for func, density in zip(functions, density_values)])
#            for material, density_values in densities.items()#prima condizione
#            for r in radii] #seconda condizione
#
#
# for material, r, weight in weights:
#     print(f"For {material}, radius {r}:")#parte dal primo materiale primo raggio e va avanti fino all'ultimo materiale ultimo raggio
#     print(f"Weight of the circle: {weight[0]:.2f}")#posizione 1 nella lista dei pesi, troncato al secondo decimale
#     print(f"Weight of the disk: {weight[1]:.2f}")
#     print(f"Weight of the sphere: {weight[2]:.2f}")
#     print()

# %%
#6\. Edit the class defintion to add an instance attribute of is_hungry = True to the Dog class. Then add a method called eat() which changes the value of is_hungry to False when called. Figure out the best way to feed each dog and then output “My dogs are hungry.” if all are hungry or “My dogs are not hungry.” if all are not hungry. The final output should look like this:

#`I have 3 dogs. 
#Tom is 6. 
#Fletcher is 7. 
#Larry is 9. 
#And they're all mammals, of course. 
#My dogs are not hungry.
#`

#```python
# Parent class: classe "genitore"
class Dog:
    species = 'mammal' #classe attributo
    
    # Initializer / Instance attributes  __init__ è un costruttore che accetta 2 parametri, nome ed età
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.is_hungry = True  # Aggiung0 l'attributo is_hungry inizializzato a True

    # instance method -- metodo di istanza che mi descrive il cane 
    def description(self):
        return "{} is {} years old".format(self.name, self.age)

    # instance method -- 
    def speak(self, sound):
        return "{} says {}".format(self.name, sound)
    
    # Aggiungo un metodo eat che imposta is_hungry su False
    def eat(self):
        self.is_hungry = False

# Child class (inherits from Dog class)
class RussellTerrier(Dog):
    def run(self, speed):
        return "{} runs {}".format(self.name, speed)

# Child class (inherits from Dog class)
class Bulldog(Dog):
    def run(self, speed):
        return "{} runs {}".format(self.name, speed)

# Function to check hunger status of all dogs
def check_hunger_status(dogs):
    if all(not dog.is_hungry for dog in dogs):
        print("My dogs are not hungry.")
    else:
        print("My dogs are hungry.")
       

# Creiamo tre istanze di cani
dog1 = Dog("Tom", 6)
dog2 = Dog("Fletcher", 7)
dog3 = Dog("Larry", 9)

# Do da mangiare ai cani
dog1.eat()
dog2.eat()
dog3.eat()

# Verifico se sono affamati
dogs = [dog1, dog2, dog3]
are_all_hungry = all(dog.is_hungry for dog in dogs)

# Stampa informazioni sui cani e se sono affamati o no
print("I have {} dogs.".format(len(dogs)))
for dog in dogs:
    print(dog.description())
print("And they're all {}s, of course.".format(dog.species))
if are_all_hungry:
    print("My dogs are hungry.")
else:
    print("My dogs are not hungry.")
# Out:
# I have 3 dogs.
# Tom is 6 years old
# Fletcher is 7 years old
# Larry is 9 years old
# And they're all mammals, of course.
# My dogs are not hungry.
